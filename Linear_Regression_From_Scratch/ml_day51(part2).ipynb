# %% [markdown]
# ### simple Linear regression using gradient descent

# %%
class GDregressor:

    def __init__(self,learning_rate,epochs):
        self.m=27.82
        self.b=-120
        self.lr=learning_rate
        self.epochs=epochs

    def fit(self,X,y):
       # calculate b using GD
       for i in range(self.epochs):
           loss_slope=-2*np.sum(y-(self.m*X.ravel())-self.b)
           self.b=self.b-(self.lr*loss_slope)
           print(i,loss_slope,self.b)
       print(self.b)  

    def predict(self,X_test):
        y_pred=m*X_test + self.b
        return y_pred

# %%
### using my own class for linear regression

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
m=29.82

# %%
# creating class for calculating b

# %%
gd=GDregressor(0.001,100)
gd.fit(X,y)
# Out:
# 0 -23541.145603484838 -96.45885439651516
# 1 -18832.916482787874 -77.62593791372728
# 2 -15066.333186230298 -62.55960472749699
# 3 -12053.06654898424 -50.50653817851275
# 4 -9642.45323918739 -40.86408493932536
# 5 -7713.962591349911 -33.15012234797545
# 6 -6171.170073079932 -26.978952274895516
# 7 -4936.936058463945 -22.04201621643157
# 8 -3949.548846771155 -18.092467369660415
# 9 -3159.6390774169245 -14.93282829224349
# 10 -2527.711261933539 -12.405117030309952
# 11 -2022.1690095468316 -10.38294802076312
# 12 -1617.735207637465 -8.765212813125654
# 13 -1294.1881661099717 -7.471024647015682
# 14 -1035.3505328879774 -6.435674114127704
# 15 -828.2804263103819 -5.607393687817322
# 16 -662.6243410483055 -4.944769346769017
# 17 -530.0994728386446 -4.4146698739303725
# 18 -424.07957827091553 -3.990590295659457
# 19 -339.2636626167326 -3.6513266330427245
# 20 -271.410930093386 -3.3799157029493383
# 21 -217.1287440747089 -3.1627869588746296
# 22 -173.70299525976702 -2.9890839636148625
# 23 -138.9623962078137 -2.850121567407049
# 24 -111.16991696625101 -2.738951650440798
# 25 -88.93593357300058 -2.6500157168677974
# 26 -71.14874685840067 -2.578866970009397
# 27 -56.91899748672044 -2.5219479725226766
# 28 -45.53519798937637 -2.4764127745333
# 29 -36.4281583915012 -2.439984616141799
# 30 -29.142526713200965 -2.410842089428598
# 31 -23.314021370560738 -2.387528068058037
# 32 -18.65121709644866 -2.3688768509615885
# 33 -14.920973677158806 -2.3539558772844296
# 34 -11.93677894172712 -2.3420190983427025
# 35 -9.549423153381696 -2.332469675189321
# 36 -7.63953852270545 -2.3248301366666158
# 37 -6.111630818164251 -2.3187185058484516
# 38 -4.889304654531415 -2.3138292011939203
# 39 -3.9114437236251263 -2.3099177574702954
# 40 -3.129154978900104 -2.306788602491395
# 41 -2.503323983120069 -2.304285278508275
# 42 -2.002659186496018 -2.3022826193217787
# 43 -1.602127349196934 -2.3006804919725816
# 44 -1.281701879357378 -2.2993987900932242
# 45 -1.0253615034859607 -2.298373428589738
# 46 -0.8202892027886364 -2.2975531393869497
# 47 -0.6562313622309546 -2.296896908024719
# 48 -0.52498508978492 -2.296371922934934
# 49 -0.41998807182789477 -2.295951934863106
# 50 -0.33599045746224476 -2.2956159444056436
# 51 -0.26879236596973755 -2.2953471520396738
# 52 -0.2150338927759492 -2.2951321181468978
# 53 -0.17202711422073236 -2.294960091032677
# 54 -0.13762169137660862 -2.2948224693413004
# 55 -0.1100973531012599 -2.294712371988199
# 56 -0.08807788248080328 -2.294624294105718
# 57 -0.07046230598464831 -2.2945538317997336
# 58 -0.05636984478772433 -2.294497461954946
# 59 -0.045095875830412524 -2.2944523660791156
# 60 -0.03607670066430302 -2.2944162893784514
# 61 -0.02886136053137278 -2.29438742801792
# 62 -0.023089088425123805 -2.294364338929495
# 63 -0.0184712707400152 -2.294345867658755
# 64 -0.014777016592120162 -2.294331090642163
# 65 -0.011821613273760079 -2.294319269028889
# 66 -0.009457290618968273 -2.29430981173827
# 67 -0.007565832495025404 -2.294302245905775
# 68 -0.006052665996179485 -2.294296193239779
# 69 -0.0048421327970373795 -2.294291351106982
# 70 -0.003873706237506269 -2.2942874774007445
# 71 -0.003098964989902697 -2.2942843784357545
# 72 -0.0024791719920358446 -2.2942818992637624
# 73 -0.0019833375934794617 -2.294279915926169
# 74 -0.001586670074829044 -2.294278329256094
# 75 -0.0012693360599769221 -2.2942770599200344
# 76 -0.0010154688479673268 -2.2942760444511863
# 77 -0.0008123750784676531 -2.294275232076108
# 78 -0.0006499000626760676 -2.2942745821760453
# 79 -0.0005199200500385359 -2.294274062255995
# 80 -0.0004159360400137757 -2.2942736463199553
# 81 -0.0003327488321716032 -2.2942733135711233
# 82 -0.00026619906581970554 -2.2942730473720574
# 83 -0.00021295925266429094 -2.294272834412805
# 84 -0.00017036740204190437 -2.294272664045403
# 85 -0.00013629392165626086 -2.2942725277514815
# 86 -0.00010903513732785086 -2.294272418716344
# 87 -8.722810988359697e-05 -2.294272331488234
# 88 -6.978248787703478e-05 -2.2942722617057463
# 89 -5.582599035136582e-05 -2.2942722058797558
# 90 -4.466079236919995e-05 -2.2942721612189634
# 91 -3.572863370493451e-05 -2.2942721254903296
# 92 -2.8582907106056155e-05 -2.2942720969074224
# 93 -2.28663256578443e-05 -2.2942720740410967
# 94 -1.8293060364271696e-05 -2.2942720557480363
# 95 -1.4634448312733639e-05 -2.294272041113588
# 96 -1.1707558570606125e-05 -2.2942720294060295
# 97 -9.366047081016404e-06 -2.2942720200399824
# 98 -7.492837681866149e-06 -2.294272012547145
# 99 -5.99427023928456e-06 -2.2942720065528746
# -2.2942720065528746

# %%
y_pred=gd.predict(X)

# %%
m=29.82
b=0
lr=0.01
epoch=100
loss_funct=[]

for i in range(epoch):
    loss_slope=-2*np.sum(y-(m*X.ravel())-b)
    loss_funct.append(loss_slope)
    b=b-(lr*loss_slope)

    y_pred1=m*X.ravel()+b
    plt.plot(X,y_pred1)

# plt.plot(X,y_pred1,color='r')
plt.scatter(X,y)

# %%
plt.plot(X,y_pred,color='r')
plt.scatter(X,y)

# %%
# various visualisations
